# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

from HANKModel import HANKModelClass
# Out:
# /var/folders/hz/45fl4vkn57b1m09564p79_rc0000gn/T/ipykernel_10992/2107754261.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # Setup

# %%
model = HANKModelClass(name='baseline')

# %%
par = model.par
ss = model.ss
path = model.path
sim = model.sim

# %% [markdown]
# # Test Household Problem

# %%
# just some ad hoc parameters
par.beta = 0.96**(1/4)
ss.ra = 1.02**(1/4)-1
ss.w = 1.0
ss.L = 1.0
ss.tau = 0.10
ss.chi = 0.0

# %%
model.solve_hh_ss(do_print=True)
model.simulate_hh_ss(do_print=True)
# Out:
# household problem in ss solved in 4.0 secs [1007 iterations]
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# household problem in ss simulated in 6.7 secs [1307 iterations]

# %%
fig = plt.figure(figsize=(18,4),dpi=100)
a_max = 10

# a. consumption
I = par.a_grid < a_max

ax = fig.add_subplot(1,3,1)
ax.set_title(f'consumption')

for i_z in [0,par.Nz//2,par.Nz-1]:
    ax.plot(par.a_grid[I],ss.c[0,i_z,I],label=f'i_z = {i_z}')

ax.legend(frameon=True)
ax.set_xlabel('savings, $a_{t-1}$')
ax.set_ylabel('consumption, $c_t$')

# b. saving
I = par.a_grid < a_max

ax = fig.add_subplot(1,3,2)
ax.set_title(f'saving')

for i_z in [0,par.Nz//2,par.Nz-1]:
    ax.plot(par.a_grid[I],ss.a[0,i_z,I],label=f'i_z = {i_z}')

ax.set_xlabel('savings, $a_{t-1}$')
ax.set_ylabel('savings, $a_{t}$')

fig.tight_layout()

# %%
fig = plt.figure(figsize=(12,4),dpi=100)

# a. income
ax = fig.add_subplot(1,2,1)
ax.set_title('productivity')

y = np.cumsum(np.sum(ss.D[0],axis=1))
ax.plot(par.z_grid,y/y[-1])

ax.set_xlabel('productivity, $z_{t}$')
ax.set_ylabel('CDF')

# b. assets
ax = fig.add_subplot(1,2,2)
ax.set_title('savings')
y = np.insert(np.cumsum(np.sum(ss.D[0],axis=0)),0,0.0)
ax.plot(np.insert(par.a_grid,0,par.a_grid[0]),y/y[-1])
        
ax.set_xlabel('assets, $a_{t}$')
ax.set_ylabel('CDF')
ax.set_xscale('symlog')

# %% [markdown]
# # Test household path

# %%
model.test_hh_path()
# Out:
# note: inputs = steady state value -> expected: constant value (straigt line)
#
# household problem solved along transition path in 0.6 secs
# household problem simulated along transition in 2.1 secs

# %% [markdown]
# # Test steady state

# %%
from steady_state import obj_ss

# %%
beta_vec = np.linspace(0.85**(1/4),1/(1+par.r_target_ss)-1e-4,5)
clearing_A_vec = np.zeros(beta_vec.size)
for i,beta in enumerate(beta_vec):
    clearing_A_vec[i] = obj_ss(beta,model,do_print=False)
    print(f'{beta = :.2f} = {clearing_A_vec[i] = :.2f}')
# Out:
# beta = 0.96 = clearing_A_vec[i] = 0.79
# beta = 0.97 = clearing_A_vec[i] = 0.53
# beta = 0.98 = clearing_A_vec[i] = -0.10
# beta = 0.99 = clearing_A_vec[i] = -2.01
# beta = 0.99 = clearing_A_vec[i] = -30.47

# %%
model.find_ss(do_print=True)
# Out:
# steady state found in 4.9 secs
#  r    =   0.0050
#  q    =   4.8789
#  qB   =   1.0000
# Discrepancy in A =   0.00000000
# Discrepancy in Y =   0.00000000

# %% [markdown]
# # Test path

# %%
model.test_path()
# Out:
# note: inputs = steady state value -> expected: no difference to steady state and zero errors
#
# difference to value at steady state:
# A              : t0 =  0.0e+00, max abs.  0.0e+00
# B              : t0 =  0.0e+00, max abs.  0.0e+00
# chi            : t0 =  0.0e+00, max abs.  0.0e+00
# clearing_A     : t0 = -3.4e-14, max abs.  2.7e-10
# clearing_Y     : t0 =  3.4e-14, max abs.  1.5e-11
# G              : t0 =  0.0e+00, max abs.  0.0e+00
# Gamma          : t0 =  0.0e+00, max abs.  0.0e+00
# i              : t0 =  0.0e+00, max abs.  0.0e+00
# L              : t0 =  0.0e+00, max abs.  0.0e+00
# pi_w           : t0 =  0.0e+00, max abs.  0.0e+00
# pi             : t0 =  0.0e+00, max abs.  0.0e+00
# q              : t0 =  0.0e+00, max abs.  0.0e+00
# r              : t0 =  0.0e+00, max abs.  0.0e+00
# ra             : t0 =  0.0e+00, max abs.  0.0e+00
# tau            : t0 =  0.0e+00, max abs.  0.0e+00
# w              : t0 =  0.0e+00, max abs.  0.0e+00
# Y              : t0 =  0.0e+00, max abs.  0.0e+00
# A_hh           : t0 =  3.4e-14, max abs.  2.7e-10
# C_hh           : t0 = -3.4e-14, max abs.  1.5e-11
#
# absolute value (potential targets):
# NKWC_res       : t0 =  8.7e-15, max abs.  3.8e-12

# %%
model.test_jacs(s_list=[50,100,150])
# Out:
# note: differences should only be due to numerical errors
#
# direct method:
# finding Jacobian wrt. ghost          : 50 100 150 [computed in 0.8 secs]
# finding Jacobian wrt. L              : 50 100 150 [computed in 0.8 secs]
# finding Jacobian wrt. chi            : 50 100 150 [computed in 0.8 secs]
# finding Jacobian wrt. ra             : 50 100 150 [computed in 0.8 secs]
# finding Jacobian wrt. tau            : 50 100 150 [computed in 0.8 secs]
# finding Jacobian wrt. w              : 50 100 150 [computed in 0.8 secs]
# household Jacobian computed in 5.3 secs
#
# fake news method:
# one step deviation from steady state calculated in 0.0 secs
# curly_Y and curly_D calculated for L               in 0.6 secs
# curly_Y and curly_D calculated for chi             in 0.5 secs
# curly_Y and curly_D calculated for ra              in 0.5 secs
# curly_Y and curly_D calculated for tau             in 0.5 secs
# curly_Y and curly_D calculated for w               in 0.7 secs
# curly_E calculated in 3.3 secs
# builiding blocks combined in 0.8 secs
# household Jacobian computed in 7.1 secs
#
# A_hh:
#  L              : cond = 1.6e+01 [mean =  2.2e-03]
#  chi            : cond = 4.3e+03 [mean = -5.3e-03]
#  ra             : cond = 2.4e+02 [mean =  1.9e-01]
#  tau            : cond = 1.6e+01 [mean = -2.8e-03]
#  w              : cond = 1.6e+01 [mean =  2.2e-03]
#
# C_hh:
#  L              : cond = 7.1e+00 [mean =  1.6e-03]
#  chi            : cond = 4.7e+00 [mean =  2.0e-03]
#  ra             : cond = 2.1e+01 [mean =  2.7e-03]
#  tau            : cond = 7.1e+00 [mean = -2.0e-03]
#  w              : cond = 7.1e+00 [mean =  1.6e-03]
#
# full Jacobian to unknowns computed in 1.2 secs [in evaluate_path(): 0.6 secs]
# full Jacobian to shocks computed in 1.4 secs [in evaluate_path(): 0.6 secs]
#
# clearing_A:
#  L              : cond = 1.7e+01 [mean = -7.0e-03]
#  G              : cond = 2.4e+01 [mean =  2.3e-02]
#  chi            : cond = 1.3e+02 [mean =  2.8e-02]
#
# NKWC_res:
#  L              : cond = 2.5e+00 [mean = -6.7e-04]
#  G              : cond = inf [mean =  2.6e-04]
#  chi            : cond = 3.2e+00 [mean = -2.5e-04]
#
# H_U            : cond = inf [mean = -1.9e-03]
# H_Z            : cond = 3.8e+02 [mean =  8.6e-03]

# %% [markdown]
# # Question 1

# %%
par.jump_G = 0.01*ss.G
par.rho_G = 0.008
model.find_transition_path(do_print=True)
# Out:
# finding the transition path:
#  it =   0 -> max. abs. error = 1.93e-03
#    1.93e-03 in clearing_A
#    1.79e-05 in NKWC_res
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In [14], line 3
#       1 par.jump_G = 0.01*ss.G
#       2 par.rho_G = 0.008
# ----> 3 model.find_transition_path(do_print=True)
#
# File ~/Emma/GEModelTools/GEModelTools/GEModelClass.py:1335, in GEModelClass.find_transition_path(self, ini, unknowns_ss, shock_specs, do_end_check, do_print, do_print_unknowns)
#    1332 obj = lambda x: self._evaluate_H(x)
#    1334 if do_print: print(f'finding the transition path:')
# -> 1335 x = broyden_solver(obj,x0,self.H_U,
#    1336     tol=par.tol_broyden,
#    1337     max_iter=par.max_iter_broyden,
#    1338     model=self,
#    1339     do_print=do_print,
#    1340     do_print_unknowns=do_print_unknowns)
#    1342 # e. final evaluation
#    1343 self._evaluate_H(x)
#
# File ~/Emma/GEModelTools/GEModelTools/broyden_solver.py:39, in broyden_solver(f, x0, jac, tol, max_iter, backtrack_fac, max_backtrack, do_print, do_print_unknowns, model, fixed_jac)
#      36 if abs_diff < tol: return x
#      38 # ii. new x
# ---> 39 dx = np.linalg.solve(jac,-y)
#      41 # iii. evalute with backtrack
#      42 for _ in range(max_backtrack):
#
# File <__array_function__ internals>:180, in solve(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py:400, in solve(a, b)
#     398 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     399 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 400 r = gufunc(a, b, signature=signature, extobj=extobj)
#     402 return wrap(r.astype(result_t, copy=False))
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py:89, in _raise_linalgerror_singular(err, flag)
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
paths = ['i','pi','r']
lvl_value = ['i','pi','r','G']
model.show_IRFs(paths,lvl_value=lvl_value,T_max=20,ncols=3)
# Out:
# ### shocks ###
# ### varnames ###
# ### tagets ###

# %% [markdown]
# # Question 2

# %%
model.find_IRFs(do_print=True)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 model.find_IRFs(do_print=True)
#
# File ~/Emma/GEModelTools/GEModelTools/GEModelClass.py:1199, in GEModelClass.find_IRFs(self, shock_specs, reuse_G_U, do_print)
#    1197 # a. solution matrix
#    1198 t0_ = time.time()
# -> 1199 if not reuse_G_U: self.G_U[:,:] = -np.linalg.solve(self.H_U,self.H_Z)
#    1200 t1_ = time.time()
#    1202 # b. set path for shocks
#
# File <__array_function__ internals>:180, in solve(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py:400, in solve(a, b)
#     398 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     399 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 400 r = gufunc(a, b, signature=signature, extobj=extobj)
#     402 return wrap(r.astype(result_t, copy=False))
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py:89, in _raise_linalgerror_singular(err, flag)
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %%
paths = ['C_hh']
lvl_value = ['G']
model.show_IRFs(paths,lvl_value=lvl_value,T_max=24,ncols=3,do_linear=True)
# Out:
# ### shocks ###
# ### varnames ###
# ### tagets ###

# %% [markdown]
# # Question 3

# %%
par.kappa = 0.5

# %% [markdown]
# # Question 4
